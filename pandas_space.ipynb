# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahdepaz/CS-APP2e/blob/master/pandas_space.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
ds = sns.load_dataset('diamonds')

# %%
ds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
ds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
ds.head(3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
ds.tail(3)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
ds.describe()
# Out:
#               carat         depth  ...             y             z
# count  53940.000000  53940.000000  ...  53940.000000  53940.000000
# mean       0.797940     61.749405  ...      5.734526      3.538734
# std        0.474011      1.432621  ...      1.142135      0.705699
# min        0.200000     43.000000  ...      0.000000      0.000000
# 25%        0.400000     61.000000  ...      4.720000      2.910000
# 50%        0.700000     61.800000  ...      5.710000      3.530000
# 75%        1.040000     62.500000  ...      6.540000      4.040000
# max        5.010000     79.000000  ...     58.900000     31.800000
#
# [8 rows x 7 columns]

# %%
sns.scatterplot(data=ds, x='carat', y='price')

# %%
sns.scatterplot(data=ds, x='carat', y='price', linewidth=0, alpha=0.05)

# %%
sns.scatterplot(data=ds, x='carat', y='price', hue='cut', linewidth=0, alpha=0.05)

# %%
ds.head(1)
# Out:
#    carat    cut color clarity  depth  table  price     x     y     z
# 0   0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43

# %%
ds['volume'] = ds.x * ds.y * ds.z

# %%
ds.head(1)
# Out:
#    carat    cut color clarity  depth  table  price     x     y     z    volume
# 0   0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43  38.20203

# %%
sns.scatterplot(data=ds, x='carat', y='volume', linewidth=0, alpha=0.1)

# %%
sns.scatterplot(data=ds, x='cut', y='volume', hue='price', linewidth=0, alpha=0.1 )

# %%
sample = ds.sample(frac=0.05)

# %%
sample.describe()
# Out:
#              carat        depth  ...            z       volume
# count  2697.000000  2697.000000  ...  2697.000000  2697.000000
# mean      0.794624    61.746719  ...     3.536633   129.242005
# std       0.468044     1.449434  ...     0.687263    75.400490
# min       0.230000    53.400000  ...     1.070000    36.487422
# 25%       0.400000    61.000000  ...     2.920000    65.466400
# 50%       0.700000    61.800000  ...     3.530000   114.965312
# 75%       1.040000    62.500000  ...     4.030000   170.316081
# max       4.130000    71.200000  ...     6.430000   633.355000
#
# [8 rows x 8 columns]

# %%
sns.pairplot(data=ds)

# %%
sns.countplot(data=ds, x='cut')

# %%
sns.boxplot(data=ds, x='carat')

# %%
sns.boxplot(data=ds, x='carat', y='cut')

# %%
sns.set_style('whitegrid')
sns.boxplot(data=ds, x='carat', y='cut')

# %%
ds.head(1)
# Out:
#    carat    cut color clarity  depth  table  price     x     y     z    volume
# 0   0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43  38.20203

# %%
labels = ['small', 'medium', 'large', 'extra large']
ds['volume_bucket'] = pd.qcut(ds['volume'], q=len(labels), labels=labels)

# %%
ds.head(1)
# Out:
#    carat    cut color clarity  depth  ...     x     y     z    volume  volume_bucket
# 0   0.23  Ideal     E     SI2   61.5  ...  3.95  3.98  2.43  38.20203          small
#
# [1 rows x 12 columns]

# %%
sns.distplot(ds['carat'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(ds['cut'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data=ds, x='cut', hue='volume_bucket')

# %%
g = sns.JointGrid(data=ds, x='carat', y='price')
g.plot(sns.regplot, sns.displot)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
pv = ds.pivot_table(index='cut', columns= ['volume_bucket'], values='price')

# %%
pv
# Out:
# volume_bucket       small       medium        large  extra large
# cut
# Ideal          767.309598  1605.132298  4052.115083  9243.296368
# Premium        789.841400  1551.286629  4215.715558  9278.588843
# Very Good      636.927732  1624.210398  4258.999721  9358.714083
# Good           639.610723  1570.941313  4221.506010  9261.315109
# Fair           879.825397  1637.419192  3575.116212  8418.275330

# %%
sns.heatmap(pv)
